# %% [markdown]
# This is just my attempt to analyse the general data of covid, globally

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('COVID-19.csv/COVID-19.csv')

# %%
data
# Out:
#       iso               country        date  \
# 0      AE  United Arab Emirates  2020-02-15
# 1      AE  United Arab Emirates  2020-02-16
# 2      AE  United Arab Emirates  2020-02-17
# 3      AE  United Arab Emirates  2020-02-18
# 4      AE  United Arab Emirates  2020-02-19
# ...    ..                   ...         ...
# 53372  ZW              Zimbabwe  2021-03-19
# 53373  ZW              Zimbabwe  2021-03-20
# 53374  ZW              Zimbabwe  2021-03-21
# 53375  ZW              Zimbabwe  2021-03-22
# 53376  ZW              Zimbabwe  2021-03-23
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                    4.0
# 1                                                    4.0
# 2                                                    1.0
# 3                                                    1.0
# 4                                                    0.0
# ...                                                  ...
# ...

# %%
data[data['iso'] == 'AE'].mean()
# Out:
# grocery_and_pharmacy_percent_change_from_baseline    -6.133995e+00
# parks_percent_change_from_baseline                   -3.778412e+01
# residential_percent_change_from_baseline              1.227295e+01
# retail_and_recreation_percent_change_from_baseline   -2.618859e+01
# transit_stations_percent_change_from_baseline        -4.136228e+01
# workplaces_percent_change_from_baseline              -2.292308e+01
# confirmed_cases                                       1.228937e+05
# confirmed_deaths                                      4.537221e+02
# gov_response_stringency_index                         5.391147e-01
# total_tests                                           1.149916e+07
# total_vaccinations                                    4.394860e+06
# people_vaccinated                                     2.158492e+06
# people_fully_vaccinated                               1.218924e+06
# gdp_ppp_per_capita                                    7.507526e+04
# ...

# %%
AE = data[data['iso'] == 'AE'].mean()

# %%
AE = pd.DataFrame(data[data['iso'] == 'AE'].mean()).transpose()

# %%
AE
# Out:
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                          -6.133995
#
#    parks_percent_change_from_baseline  \
# 0                          -37.784119
#
#    residential_percent_change_from_baseline  \
# 0                                 12.272953
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                         -26.188586
#
#    transit_stations_percent_change_from_baseline  \
# 0                                     -41.362283
#
#    workplaces_percent_change_from_baseline  confirmed_cases  confirmed_deaths  \
# 0                               -22.923077    122893.687345        453.722084
#
#    gov_response_stringency_index   total_tests  total_vaccinations  \
# 0                       0.539115  1.149916e+07        4.394860e+06
#
#    people_vaccinated  people_fully_vaccinated  gdp_ppp_per_capita  population  \
# 0          2158491.5                1218924.5            75075.26   9865845.0
#
# ...

# %%
'grocery_and_pharmacy_percent_change_from_baseline',
'parks_percent_change_from_baseline',
'residential_percent_change_from_baseline',
'retail_and_recreation_percent_change_from_baseline',
'transit_stations_percent_change_from_baseline',
'workplaces_percent_change_from_baseline',
'confirmed_cases',
'confirmed_deaths',
'gov_response_stringency_index',
'total_tests',
'total_vaccinations',
'people_vaccinated',
'people_fully_vaccinated',
'gdp_ppp_per_capita',
'population',
'population_density',
'human_development_index',
'pop_age_above_65_percentage',
'health_index'

# %%
import pandas as pd

data = {'First Column Name':  ['First value', 'Second value'],'Second Column Name': ['First value', 'Second value']}

df = pd.DataFrame (data, columns = ['First Column Name','Second Column Name',...])

print (df)

# %%
dataXX = {'iso','grocery_and_pharmacy_percent_change_from_baseline',
'parks_percent_change_from_baseline',
'residential_percent_change_from_baseline',
'retail_and_recreation_percent_change_from_baseline',
'transit_stations_percent_change_from_baseline',
'workplaces_percent_change_from_baseline',
'confirmed_cases',
'confirmed_deaths',
'gov_response_stringency_index',
'total_tests',
'total_vaccinations',
'people_vaccinated',
'people_fully_vaccinated',
'gdp_ppp_per_capita',
'population',
'population_density',
'human_development_index',
'pop_age_above_65_percentage',
'health_index'}

# %%
dataBB = data.groupby('iso')['iso','grocery_and_pharmacy_percent_change_from_baseline',
'parks_percent_change_from_baseline',
'residential_percent_change_from_baseline',
'retail_and_recreation_percent_change_from_baseline',
'transit_stations_percent_change_from_baseline',
'workplaces_percent_change_from_baseline',
'confirmed_cases',
'confirmed_deaths',
'gov_response_stringency_index',
'total_tests',
'total_vaccinations',
'people_vaccinated',
'people_fully_vaccinated',
'gdp_ppp_per_capita',
'population',
'population_density',
'human_development_index',
'pop_age_above_65_percentage',
'health_index'].mean()
# Out:
# <ipython-input-53-fc8da6904f55>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dataBB = data.groupby('iso')['iso','grocery_and_pharmacy_percent_change_from_baseline',

# %%
dataBB
# Out:
#      grocery_and_pharmacy_percent_change_from_baseline  \
# iso
# AE                                           -6.133995
# AF                                           28.510511
# AG                                          -12.632275
# AO                                           -4.158809
# AR                                          -15.451613
# ..                                                 ...
# VN                                            0.295285
# YE                                           23.570720
# ZA                                           -8.379653
# ZM                                            7.183623
# ZW                                           -0.702233
#
#      parks_percent_change_from_baseline  \
# iso
# AE                           -37.784119
# AF                             3.025140
# AG                            16.714286
# AO                             2.693122
# AR                           -63.791563
# ..                                  ...
# ...

# %%
df = pd.DataFrame(dataXX).transpose()

# %%
df
# Out:
#                                                     0
# 0                             human_development_index
# 1   grocery_and_pharmacy_percent_change_from_baseline
# 2                                   people_vaccinated
# 3                  parks_percent_change_from_baseline
# 4                                         total_tests
# 5                                          population
# 6                                  population_density
# 7                                        health_index
# 8                       gov_response_stringency_index
# 9                             people_fully_vaccinated
# 10                                 total_vaccinations
# 11            workplaces_percent_change_from_baseline
# 12                                   confirmed_deaths
# 13                                                iso
# 14      transit_stations_percent_change_from_baseline
# 15                                    confirmed_cases
# ...

# %%
unique_iso = data['iso'].unique()
unique_iso
# Out:
# array(['AE', 'AF', 'AG', 'AO', 'AR', 'AT', 'AU', 'AW', 'BA', 'BB', 'BD',
#        'BE', 'BF', 'BG', 'BH', 'BJ', 'BO', 'BR', 'BW', 'BY', 'BZ', 'CA',
#        'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CZ', 'DE', 'DK', 'DO',
#        'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FR', 'GA', 'GB', 'GE', 'GH',
#        'GR', 'GT', 'GW', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL',
#        'IN', 'IQ', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KR', 'KW',
#        'KZ', 'LA', 'LB', 'LI', 'LK', 'LT', 'LU', 'LV', 'LY', 'MA', 'MD',
#        'MK', 'ML', 'MN', 'MT', 'MU', 'MX', 'MY', 'MZ', nan, 'NE', 'NG',
#        'NI', 'NL', 'NO', 'NP', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK',
#        'PL', 'PR', 'PT', 'PY', 'QA', 'RE', 'RO', 'RS', 'RU', 'RW', 'SA',
#        'SE', 'SG', 'SI', 'SK', 'SN', 'SV', 'TG', 'TH', 'TJ', 'TR', 'TT',
#        'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'VE', 'VN', 'YE', 'ZA', 'ZM',
#        'ZW'], dtype=object)

# %%
list1 = unique_iso.tolist()
print(f'List: {list1}')
# Out:
# List: ['AE', 'AF', 'AG', 'AO', 'AR', 'AT', 'AU', 'AW', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BJ', 'BO', 'BR', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CZ', 'DE', 'DK', 'DO', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FR', 'GA', 'GB', 'GE', 'GH', 'GR', 'GT', 'GW', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LI', 'LK', 'LT', 'LU', 'LV', 'LY', 'MA', 'MD', 'MK', 'ML', 'MN', 'MT', 'MU', 'MX', 'MY', 'MZ', nan, 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PR', 'PT', 'PY', 'QA', 'RE', 'RO', 'RS', 'RU', 'RW', 'SA', 'SE', 'SG', 'SI', 'SK', 'SN', 'SV', 'TG', 'TH', 'TJ', 'TR', 'TT', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'VE', 'VN', 'YE', 'ZA', 'ZM', 'ZW']

# %%
list1
# Out:
# ['AE',
#  'AF',
#  'AG',
#  'AO',
#  'AR',
#  'AT',
#  'AU',
#  'AW',
#  'BA',
#  'BB',
#  'BD',
#  'BE',
#  'BF',
#  'BG',
#  'BH',
#  'BJ',
#  'BO',
#  'BR',
#  'BW',
#  'BY',
#  'BZ',
#  'CA',
#  'CH',
#  'CI',
#  'CL',
#  'CM',
#  'CO',
#  'CR',
#  'CV',
#  'CZ',
#  'DE',
#  'DK',
#  'DO',
#  'EC',
#  'EE',
#  'EG',
#  'ES',
#  'FI',
#  'FJ',
#  'FR',
#  'GA',
#  'GB',
#  'GE',
#  'GH',
#  'GR',
#  'GT',
#  'GW',
#  'HK',
#  'HN',
#  'HR',
#  'HT',
#  'HU',
#  'ID',
#  'IE',
#  'IL',
#  'IN',
#  'IQ',
#  'IT',
#  'JM',
#  'JO',
#  'JP',
#  'KE',
#  'KG',
#  'KH',
#  'KR',
#  'KW',
#  'KZ',
#  'LA',
#  'LB',
#  'LI',
#  'LK',
#  'LT',
#  'LU',
#  'LV',
#  'LY',
#  'MA',
#  'MD',
#  'MK',
#  'ML',
#  'MN',
#  'MT',
#  'MU',
#  'MX',
#  'MY',
#  'MZ',
#  nan,
#  'NE',
#  'NG',
#  'NI',
#  'NL',
#  'NO',
#  'NP',
#  'NZ',
#  'OM',
#  'PA',
#  'PE',
#  'PG',
#  'PH',
#  'PK',
#  'PL',
#  'PR',
#  'PT',
#  'PY',
#  'QA',
#  'RE',
#  'RO',
#  'RS',
#  'RU',
#  'RW',
#  'SA',
#  'SE',
# ...

# %%
list1.append('zion')

# %%
#full list
list1 = unique_iso.tolist()

#initial data table


#based on list get mean

#merge mean into table

#pop iso from list

# %% [markdown]
# **PART 2**

# %%
dataBB
# Out:
#      grocery_and_pharmacy_percent_change_from_baseline  \
# iso
# AE                                           -6.133995
# AF                                           28.510511
# AG                                          -12.632275
# AO                                           -4.158809
# AR                                          -15.451613
# ..                                                 ...
# VN                                            0.295285
# YE                                           23.570720
# ZA                                           -8.379653
# ZM                                            7.183623
# ZW                                           -0.702233
#
#      parks_percent_change_from_baseline  \
# iso
# AE                           -37.784119
# AF                             3.025140
# AG                            16.714286
# AO                             2.693122
# AR                           -63.791563
# ..                                  ...
# ...

# %%
dataBB.corr()
# Out:
#                                                     grocery_and_pharmacy_percent_change_from_baseline  \
# grocery_and_pharmacy_percent_change_from_baseline                                            1.000000
# parks_percent_change_from_baseline                                                           0.401248
# residential_percent_change_from_baseline                                                    -0.593186
# retail_and_recreation_percent_change_from_baseline                                           0.743656
# transit_stations_percent_change_from_baseline                                                0.654650
# workplaces_percent_change_from_baseline                                                      0.703976
# confirmed_cases                                                                             -0.012602
# confirmed_deaths                                                                            -0.036795
# ...

# %%
plt.figure(figsize=(14,12))
sns.heatmap(dataBB.corr(),cmap='Spectral')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,12))
sns.clustermap(dataBB.corr(),cmap='Spectral')

# %%
sns.pairplot(dataBB)
