# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %matplotlib inline

# %%
df = pd.read_excel('geo mapping homeless us.xls')

# %%
df
# Out:
#                                      ID          State             Variable  \
# 0            Guam - Chronic individuals           Guam  Chronic individuals
# 1        New York - Chronic individuals       New York  Chronic individuals
# 2           Maine - Chronic individuals          Maine  Chronic individuals
# 3    North Dakota - Chronic individuals   North Dakota  Chronic individuals
# 4        Delaware - Chronic individuals       Delaware  Chronic individuals
# ..                                  ...            ...                  ...
# 427                    Texas - Veterans          Texas             Veterans
# 428                  Wyoming - Veterans        Wyoming             Veterans
# 429            West Virginia - Veterans  West Virginia             Veterans
# 430                   Kansas - Veterans         Kansas             Veterans
# 431                  Montana - Veterans        Montana             Veterans
#
#      2013    2012 % Change from 2012  \
# 0      51    22.0            131.82%
# 1    4045  4324.0             -6.45%
# 2     159   222.0            -28.38%
# 3     110    81.0             35.80%
# 4      65    84.0            -22.62%
# ..    ...     ...                ...
# 427  3878  4364.0            -11.14%
# 428   137   311.0            -55.95%
# 429   329   268.0             22.76%
# 430   414   373.0             10.99%
# 431   309   323.0             -4.33%
#
#     Percentage of Total Homeless Populaiton (2013)  Rate per 10,000
# 0                                             4.0%             3.20
# 1                                             5.2%             2.06
# 2                                             5.3%             1.20
# 3                                             5.3%             1.52
# 4                                             6.9%             0.70
# ..                                             ...              ...
# 427                                          13.1%             1.47
# 428                                          14.4%             2.35
# 429                                          14.7%             1.77
# 430                                          15.4%             1.43
# 431                                          16.5%             3.04
#
# [432 rows x 8 columns]

# %%
df['State'].value_counts()
# Out:
# Montana                 8
# Kentucky                8
# New York                8
# Nebraska                8
# Guam                    8
# New Jersey              8
# District of Columbia    8
# South Dakota            8
# Utah                    8
# Oklahoma                8
# Arizona                 8
# Hawaii                  8
# Texas                   8
# Missouri                8
# Tennessee               8
# Wisconsin               8
# Indiana                 8
# Wyoming                 8
# Florida                 8
# Alabama                 8
# Pennsylvania            8
# Puerto Rico             8
# South Carolina          8
# US Virgin Islands       8
# North Dakota            8
# Iowa                    8
# Rhode Island            8
# Delaware                8
# Minnesota               8
# Ohio                    8
# Nevada                  8
# New Hampshire           8
# Connecticut             8
# Maryland                8
# New Mexico              8
# Michigan                8
# Vermont                 8
# Oregon                  8
# Massachusetts           8
# Louisiana               8
# Washington              8
# Colorado                8
# California              8
# Kansas                  8
# West Virginia           8
# Arkansas                8
# Alaska                  8
# Mississippi             8
# North Carolina          8
# Virginia                8
# Maine                   8
# Georgia                 8
# Idaho                   8
# Illinois                8
# Name: State, dtype: int64

# %%
df['Variable'].value_counts()
# Out:
# Family Households                   54
# Unaccompanied Children and youth    54
# Veterans                            54
# Chronic individuals                 54
# Homeless persons                    54
# Persons in families                 54
# Unsheltered persons                 54
# Chronic Persons in Families         54
# Name: Variable, dtype: int64

# %%
df2 = df.drop('ID',axis=1)

# %%
df2
# Out:
#              State             Variable  2013    2012 % Change from 2012  \
# 0             Guam  Chronic individuals    51    22.0            131.82%
# 1         New York  Chronic individuals  4045  4324.0             -6.45%
# 2            Maine  Chronic individuals   159   222.0            -28.38%
# 3     North Dakota  Chronic individuals   110    81.0             35.80%
# 4         Delaware  Chronic individuals    65    84.0            -22.62%
# ..             ...                  ...   ...     ...                ...
# 427          Texas             Veterans  3878  4364.0            -11.14%
# 428        Wyoming             Veterans   137   311.0            -55.95%
# 429  West Virginia             Veterans   329   268.0             22.76%
# 430         Kansas             Veterans   414   373.0             10.99%
# 431        Montana             Veterans   309   323.0             -4.33%
#
#     Percentage of Total Homeless Populaiton (2013)  Rate per 10,000
# 0                                             4.0%             3.20
# 1                                             5.2%             2.06
# 2                                             5.3%             1.20
# 3                                             5.3%             1.52
# 4                                             6.9%             0.70
# ..                                             ...              ...
# 427                                          13.1%             1.47
# 428                                          14.4%             2.35
# 429                                          14.7%             1.77
# 430                                          15.4%             1.43
# 431                                          16.5%             3.04
#
# [432 rows x 7 columns]
