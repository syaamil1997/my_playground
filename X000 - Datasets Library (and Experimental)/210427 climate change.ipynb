# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %matplotlib inline

# %%
df = pd.read_csv('climate-change-indicators-for-malaysia-1.csv')

# %%
df
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 1          Malaysia            MYS        2016
# 2          Malaysia            MYS        2015
# 3          Malaysia            MYS        2014
# 4          Malaysia            MYS        2013
# ...             ...            ...         ...
# 2208       Malaysia            MYS        1964
# 2209       Malaysia            MYS        1963
# 2210       Malaysia            MYS        1962
# 2211       Malaysia            MYS        1961
# 2212       Malaysia            MYS        1960
#
#                                 Indicator Name     Indicator Code  \
# 0                              #indicator+name    #indicator+code
# 1                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 2                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 3                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 4                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# ...                                        ...                ...
# 2208  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 2209  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 2210  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 2211  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 2212  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
#
#                      Value
# 0     #indicator+value+num
# 1                    86270
# 2          85699.697265625
# 3                    80890
# 4          80592.998046875
# ...                    ...
# 2208                29.232
# 2209                28.558
# 2210                27.895
# 2211                27.241
# 2212                26.598
#
# [2213 rows x 6 columns]
