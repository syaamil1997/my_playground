# %% [markdown]
# **IDEAS**
#
# - recommender

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
spotify_data = pd.read_csv('top50.csv',engine='python')

# %%
spotify_data.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
print(spotify_data['Genre'].nunique())

spotify_data['Genre'].unique()
# Out:
# 21
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
spotify_data.corr()
# Out:
#                   Unnamed: 0  Beats.Per.Minute    Energy  Danceability  \
# Unnamed: 0          1.000000         -0.259193  0.102649      0.122691
# Beats.Per.Minute   -0.259193          1.000000  0.043756     -0.094183
# Energy              0.102649          0.043756  1.000000      0.018254
# Danceability        0.122691         -0.094183  0.018254      1.000000
# Loudness..dB..      0.011914          0.017016  0.670794      0.016255
# Liveness            0.270659         -0.167286  0.162768     -0.149636
# Valence.            0.137329         -0.011586  0.438820      0.172829
# Length.            -0.065844         -0.139288  0.224677     -0.000185
# Acousticness..     -0.015993         -0.031450 -0.339892     -0.098165
# Speechiness.       -0.257506          0.557052 -0.089860     -0.103472
# Popularity         -0.160680          0.196097 -0.080295     -0.071413
#
#                   Loudness..dB..  Liveness  Valence.   Length.  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(spotify_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
genre_share = spotify_data["Genre"].value_counts()
genre_share
# Out:
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# brostep             2
# country rap         2
# electropop          2
# canadian pop        2
# reggaeton           2
# dfw rap             2
# reggaeton flow      2
# panamanian pop      2
# atl hip hop         1
# big room            1
# trap music          1
# boy band            1
# r&b en espanol      1
# escape room         1
# australian pop      1
# pop house           1
# Name: Genre, dtype: int64

# %%
len(spotify_data["Genre"])
# Out:
# 50

# %%
dance_pop = spotify_data[spotify_data["Genre"] == "dance pop"]
dance_pop
# Out:
#     Unnamed: 0                                         Track.Name  \
# 2            3                      boyfriend (with Social House)
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 15          16                          No Guidance (feat. Drake)
# 31          32                                            7 rings
# 34          35                                  Never Really Over
# 39          40  fuck, i'm lonely (with Anne-Marie) - from “13 ...
# 41          42                              You Need To Calm Down
# 42          43                                            Shallow
#
#       Artist.Name      Genre  Beats.Per.Minute  Energy  Danceability  \
# 2   Ariana Grande  dance pop               190      80            40
# 11       DJ Snake  dance pop                96      71            82
# 15    Chris Brown  dance pop                93      45            70
# 31  Ariana Grande  dance pop               140      32            78
# ...

# %%
len(dance_pop) / len(spotify_data["Genre"]) *100
# Out:
# 16.0

# %%
plot = genre_share.plot.pie(y='Genre', figsize=(5, 5))
